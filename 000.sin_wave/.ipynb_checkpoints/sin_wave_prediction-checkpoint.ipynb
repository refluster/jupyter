# %%
import tensorflow as tf
import numpy as np
import random

# %%
def make_mini_batch(train_data, size_of_mini_batch, length_of_sequences):
    inputs  = np.empty(0)
    outputs = np.empty(0)
    for _ in range(size_of_mini_batch):
        index   = random.randint(0, len(train_data) - length_of_sequences)
        part    = train_data[index:index + length_of_sequences]
        inputs  = np.append(inputs, part[:, 0])
        outputs = np.append(outputs, part[-1, 1])
    inputs  = inputs.reshape(-1, length_of_sequences, 1)
    outputs = outputs.reshape(-1, 1)
    return (inputs, outputs)

# %%
def make_prediction_initial(train_data, index, length_of_sequences):
    return train_data[index:index + length_of_sequences, 0]

# %%
train_data_path             = "./normal.npy"
num_of_input_nodes          = 1
num_of_hidden_nodes         = 2
num_of_output_nodes         = 1
length_of_sequences         = 50
num_of_training_epochs      = 800
length_of_initial_sequences = 50
num_of_prediction_epochs    = 100
size_of_mini_batch          = 100
learning_rate               = 0.1
forget_bias                 = 1.0

# %%
train_data = np.load(train_data_path)
print("train_data:", train_data)
# Out:
# ('train_data:', array([[  0.00000000e+00,   1.25333234e-01],
#        [  1.25333234e-01,   2.48689887e-01],
#        [  2.48689887e-01,   3.68124553e-01],
#        ...,
#        [ -3.68124553e-01,  -2.48689887e-01],
#        [ -2.48689887e-01,  -1.25333234e-01],
#        [ -1.25333234e-01,   3.92877345e-15]]))

# %%
# random seed fix
random.seed(0)
np.random.seed(0)
tf.set_random_seed(0)

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)

# %%
with tf.Graph().as_default():
    input_ph      = tf.placeholder(tf.float32, [None, length_of_sequences, num_of_input_nodes], name="input")
    supervisor_ph = tf.placeholder(tf.float32, [None, num_of_output_nodes], name="supervisor")
    istate_ph     = tf.placeholder(tf.float32, [None, num_of_hidden_nodes * 2], name="istate")

    with tf.name_scope("inference") as scope:
        weight1_var = tf.Variable(tf.truncated_normal([num_of_input_nodes, num_of_hidden_nodes], stddev=0.1), name="weight1")
        weight2_var = tf.Variable(tf.truncated_normal([num_of_hidden_nodes, num_of_output_nodes], stddev=0.1), name="weight2")
        bias1_var   = tf.Variable(tf.truncated_normal([num_of_hidden_nodes], stddev=0.1), name="bias1")
        bias2_var   = tf.Variable(tf.truncated_normal([num_of_output_nodes], stddev=0.1), name="bias2")

        in1 = tf.transpose(input_ph, [1, 0, 2])         # (batch, sequence, data) -> (sequence, batch, data)
        in2 = tf.reshape(in1, [-1, num_of_input_nodes]) # (sequence, batch, data) -> (sequence * batch, data)
        in3 = tf.matmul(in2, weight1_var) + bias1_var
        in4 = tf.split(0, length_of_sequences, in3)     # sequence * (batch, data)

        cell = tf.nn.rnn_cell.BasicLSTMCell(num_of_hidden_nodes, forget_bias=forget_bias)
        rnn_output, states_op = tf.nn.rnn(cell, in4, initial_state=istate_ph)
        output_op = tf.matmul(rnn_output[-1], weight2_var) + bias2_var

    with tf.name_scope("loss") as scope:
        square_error = tf.reduce_mean(tf.square(output_op - supervisor_ph))
        loss_op      = square_error
        tf.scalar_summary("loss", loss_op)

    with tf.name_scope("training") as scope:
        training_op = optimizer.minimize(loss_op)

    summary_op = tf.merge_all_summaries()
    init = tf.initialize_all_variables()

    with tf.Session() as sess:
        saver = tf.train.Saver()
        summary_writer = tf.train.SummaryWriter("data", graph=sess.graph)
        sess.run(init)

        for epoch in range(num_of_training_epochs):
            inputs, supervisors = make_mini_batch(train_data, size_of_mini_batch, length_of_sequences)

            train_dict = {
                input_ph:      inputs,
                supervisor_ph: supervisors,
                istate_ph:     np.zeros((size_of_mini_batch, num_of_hidden_nodes * 2)),
            }
            sess.run(training_op, feed_dict=train_dict)

            if (epoch + 1) % 10 == 0:
                summary_str, train_loss = sess.run([summary_op, loss_op], feed_dict=train_dict)
                summary_writer.add_summary(summary_str, epoch)
                print("train#%d, train loss: %e" % (epoch + 1, train_loss))

        inputs  = make_prediction_initial(train_data, 0, length_of_initial_sequences)
        outputs = np.empty(0)
        states  = np.zeros((num_of_hidden_nodes * 2)),

        print("initial:", inputs)
        np.save("initial.npy", inputs)

        for epoch in range(num_of_prediction_epochs):
            pred_dict = {
                input_ph:  inputs.reshape((1, length_of_sequences, 1)),
                istate_ph: states,
            }
            output, states = sess.run([output_op, states_op], feed_dict=pred_dict)
            print("prediction#%d, output: %f" % (epoch + 1, output))

            inputs  = np.delete(inputs, 0)
            inputs  = np.append(inputs, output)
            outputs = np.append(outputs, output)

        print("outputs:", outputs)
        np.save("output.npy", outputs)

        saver.save(sess, "data/model")
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.BasicLSTMCell object at 0x7fba0cd8f7d0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# train#10, train loss: 4.491274e-01
# train#20, train loss: 4.354679e-01
# train#30, train loss: 3.445490e-01
# train#40, train loss: 1.880898e-01
# train#50, train loss: 9.387486e-02
# train#60, train loss: 3.612114e-02
# train#70, train loss: 1.708728e-02
# train#80, train loss: 9.563223e-03
# train#90, train loss: 8.732568e-03
# train#100, train loss: 8.311673e-03
# train#110, train loss: 6.626495e-03
# train#120, train loss: 5.949011e-03
# train#130, train loss: 5.359269e-03
# train#140, train loss: 6.212281e-03
# train#150, train loss: 5.502782e-03
# train#160, train loss: 5.369322e-03
# train#170, train loss: 4.672307e-03
# train#180, train loss: 4.525892e-03
# train#190, train loss: 4.646229e-03
# train#200, train loss: 3.776362e-03
# train#210, train loss: 4.126414e-03
# train#220, train loss: 3.865011e-03
# train#230, train loss: 2.803881e-03
# train#240, train loss: 2.829138e-03
# train#250, train loss: 3.255162e-03
# train#260, train loss: 2.890126e-03
# train#270, train loss: 2.734025e-03
# train#280, train loss: 3.022304e-03
# train#290, train loss: 3.000472e-03
# train#300, train loss: 2.243913e-03
# train#310, train loss: 3.883434e-03
# train#320, train loss: 2.335745e-03
# train#330, train loss: 2.005831e-03
# train#340, train loss: 1.939470e-03
# train#350, train loss: 1.959398e-03
# train#360, train loss: 2.346592e-03
# train#370, train loss: 4.251915e-03
# train#380, train loss: 2.072887e-03
# train#390, train loss: 1.799614e-03
# train#400, train loss: 1.701013e-03
# train#410, train loss: 1.746260e-03
# train#420, train loss: 1.436366e-03
# train#430, train loss: 2.655079e-03
# train#440, train loss: 1.259987e-03
# train#450, train loss: 1.708639e-03
# train#460, train loss: 1.193234e-03
# train#470, train loss: 1.272948e-03
# train#480, train loss: 1.352972e-03
# train#490, train loss: 1.417081e-03
# train#500, train loss: 1.371971e-03
# train#510, train loss: 1.323036e-03
# train#520, train loss: 1.517743e-03
# train#530, train loss: 1.203716e-03
# train#540, train loss: 1.175750e-03
# train#550, train loss: 1.159882e-03
# train#560, train loss: 1.732535e-03
# train#570, train loss: 1.154418e-03
# train#580, train loss: 1.357684e-03
# train#590, train loss: 1.172439e-03
# train#600, train loss: 1.008045e-03
# train#610, train loss: 1.787137e-03
# train#620, train loss: 1.129320e-03
# train#630, train loss: 1.194798e-03
# train#640, train loss: 9.216068e-04
# train#650, train loss: 1.054297e-03
# train#660, train loss: 1.025854e-03
# train#670, train loss: 8.190906e-04
# train#680, train loss: 1.108970e-03
# train#690, train loss: 9.517859e-04
# train#700, train loss: 9.517092e-04
# train#710, train loss: 3.262563e-03
# train#720, train loss: 1.621850e-03
# train#730, train loss: 8.863775e-04
# train#740, train loss: 9.430978e-04
# train#750, train loss: 8.729850e-04
# train#760, train loss: 8.956857e-04
# train#770, train loss: 7.595930e-04
# train#780, train loss: 1.662883e-03
# train#790, train loss: 1.031004e-03
# train#800, train loss: 6.989902e-04
# ('initial:', array([  0.00000000e+00,   1.25333234e-01,   2.48689887e-01,
#          3.68124553e-01,   4.81753674e-01,   5.87785252e-01,
#          6.84547106e-01,   7.70513243e-01,   8.44327926e-01,
#          9.04827052e-01,   9.51056516e-01,   9.82287251e-01,
#          9.98026728e-01,   9.98026728e-01,   9.82287251e-01,
#          9.51056516e-01,   9.04827052e-01,   8.44327926e-01,
#          7.70513243e-01,   6.84547106e-01,   5.87785252e-01,
#          4.81753674e-01,   3.68124553e-01,   2.48689887e-01,
#          1.25333234e-01,  -3.21624530e-16,  -1.25333234e-01,
#         -2.48689887e-01,  -3.68124553e-01,  -4.81753674e-01,
#         -5.87785252e-01,  -6.84547106e-01,  -7.70513243e-01,
#         -8.44327926e-01,  -9.04827052e-01,  -9.51056516e-01,
#         -9.82287251e-01,  -9.98026728e-01,  -9.98026728e-01,
#         -9.82287251e-01,  -9.51056516e-01,  -9.04827052e-01,
#         -8.44327926e-01,  -7.70513243e-01,  -6.84547106e-01,
#         -5.87785252e-01,  -4.81753674e-01,  -3.68124553e-01,
#         -2.48689887e-01,  -1.25333234e-01]))
# prediction#1, output: 0.013087
# prediction#2, output: 0.157922
# prediction#3, output: 0.298802
# prediction#4, output: 0.430444
# prediction#5, output: 0.548746
# prediction#6, output: 0.651477
# prediction#7, output: 0.737985
# prediction#8, output: 0.808641
# prediction#9, output: 0.864347
# prediction#10, output: 0.906213
# prediction#11, output: 0.935374
# prediction#12, output: 0.952867
# prediction#13, output: 0.959543
# prediction#14, output: 0.955999
# prediction#15, output: 0.942502
# prediction#16, output: 0.918921
# prediction#17, output: 0.884662
# prediction#18, output: 0.838591
# prediction#19, output: 0.779003
# prediction#20, output: 0.703693
# prediction#21, output: 0.610323
# prediction#22, output: 0.497382
# prediction#23, output: 0.365999
# prediction#24, output: 0.222077
# prediction#25, output: 0.076521
# prediction#26, output: -0.058862
# prediction#27, output: -0.177638
# prediction#28, output: -0.281177
# prediction#29, output: -0.375897
# prediction#30, output: -0.469231
# prediction#31, output: -0.566788
# prediction#32, output: -0.670247
# prediction#33, output: -0.775317
# prediction#34, output: -0.871197
# prediction#35, output: -0.944691
# prediction#36, output: -0.988050
# prediction#37, output: -1.002558
# prediction#38, output: -0.994518
# prediction#39, output: -0.970168
# prediction#40, output: -0.933816
# prediction#41, output: -0.887931
# prediction#42, output: -0.833652
# prediction#43, output: -0.771219
# prediction#44, output: -0.700262
# prediction#45, output: -0.620021
# prediction#46, output: -0.529532
# prediction#47, output: -0.427897
# prediction#48, output: -0.314675
# prediction#49, output: -0.190400
# prediction#50, output: -0.057106
# prediction#51, output: 0.081443
# prediction#52, output: 0.220096
# prediction#53, output: 0.353267
# prediction#54, output: 0.476115
# prediction#55, output: 0.585338
# prediction#56, output: 0.679291
# prediction#57, output: 0.757623
# prediction#58, output: 0.820789
# prediction#59, output: 0.869653
# prediction#60, output: 0.905235
# prediction#61, output: 0.928539
# prediction#62, output: 0.940447
# prediction#63, output: 0.941625
# prediction#64, output: 0.932446
# prediction#65, output: 0.912914
# prediction#66, output: 0.882589
# prediction#67, output: 0.840513
# prediction#68, output: 0.785162
# prediction#69, output: 0.714482
# prediction#70, output: 0.626169
# prediction#71, output: 0.518454
# prediction#72, output: 0.391708
# prediction#73, output: 0.250588
# prediction#74, output: 0.104943
# prediction#75, output: -0.033229
# prediction#76, output: -0.155959
# prediction#77, output: -0.262955
# prediction#78, output: -0.359793
# prediction#79, output: -0.453861
# prediction#80, output: -0.551193
# prediction#81, output: -0.654220
# prediction#82, output: -0.759663
# prediction#83, output: -0.857615
# prediction#84, output: -0.934861
# prediction#85, output: -0.982543
# prediction#86, output: -1.000804
# prediction#87, output: -0.995579
# prediction#88, output: -0.973273
# prediction#89, output: -0.938463
# prediction#90, output: -0.893845
# prediction#91, output: -0.840718
# prediction#92, output: -0.779432
# prediction#93, output: -0.709687
# prediction#94, output: -0.630761
# prediction#95, output: -0.541708
# prediction#96, output: -0.441617
# prediction#97, output: -0.329977
# prediction#98, output: -0.207175
# prediction#99, output: -0.075010
# prediction#100, output: 0.062998
# ('outputs:', array([ 0.01308727,  0.15792242,  0.29880181,  0.43044415,  0.54874587,
#         0.65147668,  0.73798513,  0.80864143,  0.86434674,  0.90621328,
#         0.9353745 ,  0.95286679,  0.95954347,  0.95599914,  0.94250154,
#         0.91892111,  0.88466167,  0.83859062,  0.7790029 ,  0.70369303,
#         0.61032307,  0.49738178,  0.36599877,  0.22207692,  0.07652124,
#        -0.05886243, -0.1776382 , -0.28117746, -0.37589723, -0.46923131,
#        -0.5667882 , -0.67024738, -0.77531677, -0.8711971 , -0.94469148,
#        -0.98804957, -1.00255823, -0.99451792, -0.97016793, -0.93381602,
#        -0.88793123, -0.8336525 , -0.77121854, -0.70026231, -0.6200211 ,
#        -0.52953225, -0.42789745, -0.31467476, -0.19040027, -0.05710591,
#         0.08144283,  0.22009605,  0.35326692,  0.47611484,  0.58533788,
#         0.67929107,  0.75762314,  0.8207885 ,  0.86965322,  0.90523481,
#         0.9285388 ,  0.94044662,  0.94162488,  0.932446  ,  0.91291416,
#         0.8825891 ,  0.84051299,  0.78516179,  0.71448249,  0.62616903,
#         0.51845413,  0.39170781,  0.25058845,  0.10494324, -0.03322912,
#        -0.15595886, -0.26295477, -0.35979289, -0.45386124, -0.5511933 ,
#        -0.65421951, -0.75966328, -0.85761505, -0.93486059, -0.98254293,
#        -1.00080395, -0.995579  , -0.97327256, -0.93846315, -0.89384472,
#        -0.84071827, -0.77943152, -0.70968699, -0.63076109, -0.54170835,
#        -0.44161695, -0.32997745, -0.2071749 , -0.07501025,  0.06299836]))
