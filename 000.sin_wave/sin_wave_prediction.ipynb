# %%
import tensorflow as tf
import numpy as np
import random
import pandas as pd
# %matplotlib inline

# %%
def make_mini_batch(train_data, size_of_mini_batch, length_of_sequences):
    inputs  = np.empty(0)
    outputs = np.empty(0)
    for _ in range(size_of_mini_batch):
        index   = random.randint(0, len(train_data) - length_of_sequences)
        part    = train_data[index:index + length_of_sequences]
        inputs  = np.append(inputs, part[:, 0])
        outputs = np.append(outputs, part[-1, 1])
    inputs  = inputs.reshape(-1, length_of_sequences, 1)
    outputs = outputs.reshape(-1, 1)
    return (inputs, outputs)

# %%
def make_prediction_initial(train_data, index, length_of_sequences):
    return train_data[index:index + length_of_sequences, 0]

# %%
train_data_path             = "./sin.npy"
num_of_input_nodes          = 1
num_of_hidden_nodes         = 10
num_of_output_nodes         = 1
length_of_sequences         = 30
num_of_training_epochs      = 400
length_of_initial_sequences = 30
num_of_prediction_epochs    = 100
size_of_mini_batch          = 100
learning_rate               = 0.1
forget_bias                 = 1.0

# %%
train_data = np.load(train_data_path)
print("train_data:", train_data[:10])
# Out:
# ('train_data:', array([[ 0.        ,  0.25066647],
#        [ 0.25066647,  0.49737977],
#        [ 0.49737977,  0.73624911],
#        [ 0.73624911,  0.96350735],
#        [ 0.96350735,  1.1755705 ],
#        [ 1.1755705 ,  1.36909421],
#        [ 1.36909421,  1.54102649],
#        [ 1.54102649,  1.68865585],
#        [ 1.68865585,  1.8096541 ],
#        [ 1.8096541 ,  1.90211303]]))

# %%
# random seed fix
random.seed(0)
np.random.seed(0)
tf.set_random_seed(0)

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)

with tf.Graph().as_default():
    input_ph      = tf.placeholder(tf.float32, [None, length_of_sequences, num_of_input_nodes], name="input")
    supervisor_ph = tf.placeholder(tf.float32, [None, num_of_output_nodes], name="supervisor")
    istate_ph     = tf.placeholder(tf.float32, [None, num_of_hidden_nodes * 2], name="istate")

    with tf.name_scope("inference") as scope:
        weight1_var = tf.Variable(tf.truncated_normal([num_of_input_nodes, num_of_hidden_nodes], stddev=0.1), name="weight1")
        weight2_var = tf.Variable(tf.truncated_normal([num_of_hidden_nodes, num_of_output_nodes], stddev=0.1), name="weight2")
        bias1_var   = tf.Variable(tf.truncated_normal([num_of_hidden_nodes], stddev=0.1), name="bias1")
        bias2_var   = tf.Variable(tf.truncated_normal([num_of_output_nodes], stddev=0.1), name="bias2")
        
        weight1_hist = tf.histogram_summary("layer1/weights", weight1_var)
        weight2_hist = tf.histogram_summary("layer2/weights", weight2_var)
        bias1_hist = tf.histogram_summary("layer1/biases", bias1_var)
        bias2_hist = tf.histogram_summary("layer2/biases", bias2_var)
        
        in1 = tf.transpose(input_ph, [1, 0, 2])         # (batch, sequence, data) -> (sequence, batch, data)
        in2 = tf.reshape(in1, [-1, num_of_input_nodes]) # (sequence, batch, data) -> (sequence * batch, data)
        in3 = tf.matmul(in2, weight1_var) + bias1_var
        in4 = tf.split(0, length_of_sequences, in3)     # sequence * (batch, data)

        cell = tf.nn.rnn_cell.BasicLSTMCell(num_of_hidden_nodes, forget_bias=forget_bias)
        rnn_output, states_op = tf.nn.rnn(cell, in4, initial_state=istate_ph)
        output_op = tf.matmul(rnn_output[-1], weight2_var) + bias2_var

    with tf.name_scope("loss") as scope:
        square_error = tf.reduce_mean(tf.square(output_op - supervisor_ph))
        loss_op      = square_error
        tf.scalar_summary("loss", loss_op)

    with tf.name_scope("training") as scope:
        training_op = optimizer.minimize(loss_op)

    summary_op = tf.merge_all_summaries()
    init = tf.initialize_all_variables()

    with tf.Session() as sess:
        saver = tf.train.Saver()
        summary_writer = tf.train.SummaryWriter("data", graph=sess.graph)
        sess.run(init)

        for epoch in range(num_of_training_epochs):
            inputs, supervisors = make_mini_batch(train_data, size_of_mini_batch, length_of_sequences)

            train_dict = {
                input_ph:      inputs,
                supervisor_ph: supervisors,
                istate_ph:     np.zeros((size_of_mini_batch, num_of_hidden_nodes * 2)),
            }
            sess.run(training_op, feed_dict=train_dict)

            if (epoch + 1) % 10 == 0:
                summary_str, train_loss = sess.run([summary_op, loss_op], feed_dict=train_dict)
                summary_writer.add_summary(summary_str, epoch)
                print("train#%d, train loss: %e" % (epoch + 1, train_loss))
#            if (epoch + 1) % 50 == 0:
#                rnn_output_v = sess.run(rnn_output, feed_dict=train_dict)
#                print(" rnn_output {}".format(rnn_output_v[-1]))

        inputs  = make_prediction_initial(train_data, 0, length_of_initial_sequences)
        outputs = np.empty(0)
        states  = np.zeros((num_of_hidden_nodes * 2)),

        print("initial:", inputs)
        np.save("initial.npy", inputs)

        for epoch in range(num_of_prediction_epochs):
            pred_dict = {
                input_ph:  inputs.reshape((1, length_of_sequences, 1)),
                istate_ph: states,
            }
            output, states = sess.run([output_op, states_op], feed_dict=pred_dict)
            print("prediction#%d, output: %f" % (epoch + 1, output))

            inputs  = np.delete(inputs, 0)
            inputs  = np.append(inputs, output)
            outputs = np.append(outputs, output)

        print("outputs:", outputs)
        np.save("output.npy", outputs)

        saver.save(sess, "data/model")
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.BasicLSTMCell object at 0x7f9362b1f8d0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# train#10, train loss: 5.625951e-01
# train#20, train loss: 5.661723e-02
# train#30, train loss: 2.144414e-02
# train#40, train loss: 1.665445e-02
# train#50, train loss: 6.800339e-03
# train#60, train loss: 4.401741e-03
# train#70, train loss: 2.450693e-03
# train#80, train loss: 1.456132e-03
# train#90, train loss: 1.000163e-03
# train#100, train loss: 1.243553e-03
# train#110, train loss: 1.158298e-03
# train#120, train loss: 8.685333e-04
# train#130, train loss: 8.903560e-04
# train#140, train loss: 1.471702e-03
# train#150, train loss: 6.185614e-04
# train#160, train loss: 5.985487e-04
# train#170, train loss: 5.586204e-04
# train#180, train loss: 6.011687e-04
# train#190, train loss: 6.070394e-04
# train#200, train loss: 5.848721e-04
# train#210, train loss: 4.656026e-04
# train#220, train loss: 4.620160e-04
# train#230, train loss: 5.283157e-04
# train#240, train loss: 7.741472e-04
# train#250, train loss: 5.399532e-04
# train#260, train loss: 3.860152e-04
# train#270, train loss: 4.000524e-04
# train#280, train loss: 2.953278e-04
# train#290, train loss: 3.420414e-04
# train#300, train loss: 2.870618e-04
# train#310, train loss: 2.896780e-04
# train#320, train loss: 3.243975e-04
# train#330, train loss: 2.691714e-04
# train#340, train loss: 2.390202e-04
# train#350, train loss: 2.537232e-04
# train#360, train loss: 2.791092e-04
# train#370, train loss: 2.433771e-04
# train#380, train loss: 2.030287e-04
# train#390, train loss: 2.356494e-04
# train#400, train loss: 2.567400e-04
# ('initial:', array([  0.00000000e+00,   2.50666467e-01,   4.97379774e-01,
#          7.36249105e-01,   9.63507348e-01,   1.17557050e+00,
#          1.36909421e+00,   1.54102649e+00,   1.68865585e+00,
#          1.80965410e+00,   1.90211303e+00,   1.96457450e+00,
#          1.99605346e+00,   1.99605346e+00,   1.96457450e+00,
#          1.90211303e+00,   1.80965410e+00,   1.68865585e+00,
#          1.54102649e+00,   1.36909421e+00,   1.17557050e+00,
#          9.63507348e-01,   7.36249105e-01,   4.97379774e-01,
#          2.50666467e-01,  -6.43249060e-16,  -2.50666467e-01,
#         -4.97379774e-01,  -7.36249105e-01,  -9.63507348e-01]))
# prediction#1, output: -1.198284
# prediction#2, output: -1.302733
# prediction#3, output: -1.493726
# prediction#4, output: -1.651605
# prediction#5, output: -1.785177
# prediction#6, output: -1.887534
# prediction#7, output: -1.956347
# prediction#8, output: -1.992110
# prediction#9, output: -1.997097
# prediction#10, output: -1.973834
# prediction#11, output: -1.923276
# prediction#12, output: -1.844069
# prediction#13, output: -1.732760
# prediction#14, output: -1.584908
# prediction#15, output: -1.397890
# prediction#16, output: -1.175361
# prediction#17, output: -0.929289
# prediction#18, output: -0.674059
# prediction#19, output: -0.418206
# prediction#20, output: -0.164709
# prediction#21, output: 0.083344
# prediction#22, output: 0.321328
# prediction#23, output: 0.546984
# prediction#24, output: 0.762904
# prediction#25, output: 0.973347
# prediction#26, output: 1.179360
# prediction#27, output: 1.376833
# prediction#28, output: 1.557840
# prediction#29, output: 1.713406
# prediction#30, output: 1.836194
# prediction#31, output: 1.922718
# prediction#32, output: 1.973899
# prediction#33, output: 1.993434
# prediction#34, output: 1.985106
# prediction#35, output: 1.951674
# prediction#36, output: 1.894292
# prediction#37, output: 1.812661
# prediction#38, output: 1.705144
# prediction#39, output: 1.568220
# prediction#40, output: 1.394328
# prediction#41, output: 1.168474
# prediction#42, output: 0.882638
# prediction#43, output: 0.617706
# prediction#44, output: 0.456209
# prediction#45, output: 0.336151
# prediction#46, output: 0.211401
# prediction#47, output: 0.063343
# prediction#48, output: -0.114211
# prediction#49, output: -0.323258
# prediction#50, output: -0.558635
# prediction#51, output: -0.805077
# prediction#52, output: -1.042569
# prediction#53, output: -1.257641
# prediction#54, output: -1.447838
# prediction#55, output: -1.615212
# prediction#56, output: -1.757232
# prediction#57, output: -1.866418
# prediction#58, output: -1.939463
# prediction#59, output: -1.978287
# prediction#60, output: -1.986369
# prediction#61, output: -1.966994
# prediction#62, output: -1.921686
# prediction#63, output: -1.849416
# prediction#64, output: -1.746481
# prediction#65, output: -1.607163
# prediction#66, output: -1.426564
# prediction#67, output: -1.206714
# prediction#68, output: -0.960746
# prediction#69, output: -0.705447
# prediction#70, output: -0.450067
# prediction#71, output: -0.197106
# prediction#72, output: 0.050809
# prediction#73, output: 0.288936
# prediction#74, output: 0.514611
# prediction#75, output: 0.730254
# prediction#76, output: 0.940298
# prediction#77, output: 1.146546
# prediction#78, output: 1.345732
# prediction#79, output: 1.530292
# prediction#80, output: 1.690932
# prediction#81, output: 1.819564
# prediction#82, output: 1.911851
# prediction#83, output: 1.968154
# prediction#84, output: 1.991974
# prediction#85, output: 1.987396
# prediction#86, output: 1.957412
# prediction#87, output: 1.903408
# prediction#88, output: 1.825263
# prediction#89, output: 1.721515
# prediction#90, output: 1.588966
# prediction#91, output: 1.420819
# prediction#92, output: 1.203199
# prediction#93, output: 0.924115
# prediction#94, output: 0.648181
# prediction#95, output: 0.475198
# prediction#96, output: 0.352973
# prediction#97, output: 0.230550
# prediction#98, output: 0.086187
# prediction#99, output: -0.087037
# prediction#100, output: -0.291756
# ('outputs:', array([-1.19828391, -1.30273318, -1.49372625, -1.65160537, -1.78517735,
#        -1.88753366, -1.95634651, -1.99211013, -1.99709702, -1.97383404,
#        -1.92327583, -1.84406948, -1.73276019, -1.58490849, -1.39788985,
#        -1.17536092, -0.92928869, -0.67405921, -0.41820613, -0.16470948,
#         0.08334423,  0.32132757,  0.54698384,  0.76290405,  0.97334737,
#         1.17936039,  1.37683272,  1.55783951,  1.71340644,  1.83619368,
#         1.92271769,  1.97389925,  1.99343359,  1.98510563,  1.95167363,
#         1.89429224,  1.81266081,  1.70514381,  1.56822014,  1.394328  ,
#         1.16847408,  0.88263839,  0.61770564,  0.45620915,  0.33615106,
#         0.21140143,  0.06334328, -0.11421068, -0.32325813, -0.55863506,
#        -0.80507737, -1.04256904, -1.25764084, -1.44783771, -1.61521208,
#        -1.75723243, -1.86641765, -1.93946278, -1.97828698, -1.98636925,
#        -1.96699429, -1.92168617, -1.84941578, -1.74648082, -1.60716295,
#        -1.42656434, -1.20671427, -0.96074551, -0.70544744, -0.45006695,
#        -0.19710612,  0.05080854,  0.28893644,  0.51461071,  0.7302537 ,
#         0.94029802,  1.14654565,  1.34573221,  1.53029203,  1.69093168,
#         1.81956363,  1.91185129,  1.96815431,  1.99197447,  1.98739564,
#         1.95741189,  1.90340769,  1.8252629 ,  1.72151506,  1.58896589,
#         1.42081881,  1.20319855,  0.92411536,  0.64818084,  0.47519782,
#         0.35297254,  0.23054981,  0.08618679, -0.08703727, -0.29175571]))

# %%
pred = np.load('output.npy')
print("len of pred: {}".format(len(pred)))
df = pd.DataFrame({'supervisor': train_data[length_of_initial_sequences:length_of_initial_sequences+len(pred),0], 'prediction': pred})
df.plot()
# Out:
# len of pred: 100

# %%
df = pd.DataFrame({'t': train_data[0:len(pred),0], 's': train_data[0:len(pred),1]})
df.head(600).plot()
