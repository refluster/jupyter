# %%
# predict rssi value for [num_of_prediction_epochs] time step from current time value
import tensorflow as tf
import numpy as np
import random
import pandas as pd
# %matplotlib inline

# %%
def make_mini_batch(train_data, size_of_mini_batch, length_of_sequences):
    inputs  = np.empty(0)
    outputs = np.empty(0)
    for _ in range(size_of_mini_batch):
        index   = random.randint(0, len(train_data) - length_of_sequences)
        part    = train_data[index:index + length_of_sequences]
        inputs  = np.append(inputs, part[:, 0])
        outputs = np.append(outputs, part[-1, 1])
    inputs  = inputs.reshape(-1, length_of_sequences, 1)
    outputs = outputs.reshape(-1, 1)
    return (inputs, outputs)

# %%
def make_prediction_initial(train_data, index, length_of_sequences):
    return train_data[index:index + length_of_sequences, 0]

# %%
train_data_path             = "./rssi_next.npy"
num_of_input_nodes          = 1
num_of_hidden_nodes         = 20
num_of_output_nodes         = 1
length_of_sequences         = 30
num_of_training_epochs      = 800
length_of_initial_sequences = 30
num_of_prediction_epochs    = 100
size_of_mini_batch          = 100
learning_rate               = 0.1
forget_bias                 = 1.0

# %%
train_data = np.load(train_data_path)

# %%
#optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
#optimizer = tf.train.AdagradOptimizer(learning_rate=learning_rate)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

with tf.Graph().as_default():
    input_ph      = tf.placeholder(tf.float32, [None, length_of_sequences, num_of_input_nodes], name="input")
    supervisor_ph = tf.placeholder(tf.float32, [None, num_of_output_nodes], name="supervisor")

    with tf.name_scope("inference") as scope:
        weight1_var = tf.Variable(tf.truncated_normal([num_of_input_nodes, num_of_hidden_nodes], stddev=0.1), name="weight1")
        weight2_var = tf.Variable(tf.truncated_normal([num_of_hidden_nodes, num_of_output_nodes], stddev=0.1), name="weight2")
        bias1_var   = tf.Variable(tf.truncated_normal([num_of_hidden_nodes], stddev=0.1), name="bias1")
        bias2_var   = tf.Variable(tf.truncated_normal([num_of_output_nodes], stddev=0.1), name="bias2")

        weight1_hist = tf.histogram_summary("layer1/weights", weight1_var)
        weight2_hist = tf.histogram_summary("layer2/weights", weight2_var)
        bias1_hist = tf.histogram_summary("layer1/biases", bias1_var)
        bias2_hist = tf.histogram_summary("layer2/biases", bias2_var)
        
        # normalize
        in0 = (input_ph + 60) / 15
        
        # pre rnn
        in1 = tf.transpose(in0, [1, 0, 2])         # (batch, sequence, data) -> (sequence, batch, data)
        in2 = tf.reshape(in1, [-1, num_of_input_nodes]) # (sequence, batch, data) -> (sequence * batch, data)
        in3 = tf.matmul(in2, weight1_var) + bias1_var
        in4 = tf.split(0, length_of_sequences, in3)     # sequence * (batch, data)

        cell = tf.nn.rnn_cell.BasicLSTMCell(num_of_hidden_nodes, forget_bias=forget_bias, state_is_tuple=True)
        istate_ph = cell.zero_state(size_of_mini_batch, tf.float32)
        rnn_output, states_op = tf.nn.rnn(cell, in4, dtype=tf.float32)
        
        # post rnn
        out0 = tf.matmul(rnn_output[-1], weight2_var) + bias2_var
        
        # denormalize
        output_op = out0 * 15 - 60

    with tf.name_scope("loss") as scope:
        square_error = tf.reduce_mean(tf.square(output_op - supervisor_ph))
        loss_op      = square_error
        tf.scalar_summary("loss", loss_op)

    with tf.name_scope("training") as scope:
        training_op = optimizer.minimize(loss_op)

    summary_op = tf.merge_all_summaries()
    init = tf.initialize_all_variables()

    with tf.Session() as sess:
        saver = tf.train.Saver()
        summary_writer = tf.train.SummaryWriter("data", graph=sess.graph)
        # random seed fix
        random.seed(0)
        np.random.seed(0)
        tf.set_random_seed(0)
        # init variables
        sess.run(init)

        for epoch in range(num_of_training_epochs):
            inputs, supervisors = make_mini_batch(train_data, size_of_mini_batch, length_of_sequences)
            state = sess.run(istate_ph)

            train_dict = {
                input_ph:      inputs,
                supervisor_ph: supervisors,
            }
            sess.run(training_op, feed_dict=train_dict)

            if (epoch + 1) % 10 == 0:
                summary_str, train_loss = sess.run([summary_op, loss_op], feed_dict=train_dict)
                summary_writer.add_summary(summary_str, epoch)
                print("train#%d, train loss: %e" % (epoch + 1, train_loss))

        inputs  = make_prediction_initial(train_data, 0, length_of_initial_sequences)
        outputs = np.empty(0)

        print("initial:", inputs)
        np.save("initial.npy", inputs)

        istate_ph = cell.zero_state(1, tf.float32)
        sess.run(istate_ph)

        for epoch in range(num_of_prediction_epochs):
            pred_dict = {
                input_ph:  inputs.reshape((1, length_of_sequences, 1)),
            }
            output, states = sess.run([output_op, states_op], feed_dict=pred_dict)
            print("prediction#%d, output: %f" % (epoch + 1, output))

            inputs  = np.delete(inputs, 0)
            inputs  = np.append(inputs, output)
            outputs = np.append(outputs, output)
        
        print("outputs:", outputs)
        np.save("output.npy", outputs)

        saver.save(sess, "data/model")
# Out:
# train#10, train loss: 5.677039e+00
# train#20, train loss: 1.688833e+00
# train#30, train loss: 1.320690e+00
# train#40, train loss: 1.159129e+00
# train#50, train loss: 1.041358e+00
# train#60, train loss: 1.100473e+00
# train#70, train loss: 1.105873e+00
# train#80, train loss: 1.127656e+00
# train#90, train loss: 1.280147e+00
# train#100, train loss: 1.045758e+00
# train#110, train loss: 1.045455e+00
# train#120, train loss: 1.213082e+00
# train#130, train loss: 1.113424e+00
# train#140, train loss: 1.015373e+00
# train#150, train loss: 1.251023e+00
# train#160, train loss: 8.250673e-01
# train#170, train loss: 1.275798e+00
# train#180, train loss: 1.293053e+00
# train#190, train loss: 1.076456e+00
# train#200, train loss: 1.255519e+00
# train#210, train loss: 1.581447e+00
# train#220, train loss: 1.116811e+00
# train#230, train loss: 1.129294e+00
# train#240, train loss: 9.386396e-01
# train#250, train loss: 1.200651e+00
# train#260, train loss: 1.463350e+00
# train#270, train loss: 8.070149e-01
# train#280, train loss: 9.300247e-01
# train#290, train loss: 1.109643e+00
# train#300, train loss: 1.292668e+00
# train#310, train loss: 9.753077e-01
# train#320, train loss: 1.054062e+00
# train#330, train loss: 1.178440e+00
# train#340, train loss: 1.116494e+00
# train#350, train loss: 1.081128e+00
# train#360, train loss: 1.100023e+00
# train#370, train loss: 9.507979e-01
# train#380, train loss: 7.755504e-01
# train#390, train loss: 8.928291e-01
# train#400, train loss: 1.199796e+00
# train#410, train loss: 8.343481e-01
# train#420, train loss: 1.009618e+00
# train#430, train loss: 9.477313e-01
# train#440, train loss: 8.824626e-01
# train#450, train loss: 8.467468e-01
# train#460, train loss: 8.121679e-01
# train#470, train loss: 8.232744e-01
# train#480, train loss: 9.052742e-01
# train#490, train loss: 1.077846e+00
# train#500, train loss: 1.159811e+00
# train#510, train loss: 1.302143e+00
# train#520, train loss: 1.526851e+00
# train#530, train loss: 1.346854e+00
# train#540, train loss: 1.314595e+00
# train#550, train loss: 1.180633e+00
# train#560, train loss: 8.135467e-01
# train#570, train loss: 9.559962e-01
# train#580, train loss: 8.222496e-01
# train#590, train loss: 7.944778e-01
# train#600, train loss: 8.806512e-01
# train#610, train loss: 9.340745e-01
# train#620, train loss: 6.944852e-01
# train#630, train loss: 8.053365e-01
# train#640, train loss: 8.685747e-01
# train#650, train loss: 9.578418e-01
# train#660, train loss: 5.897336e-01
# train#670, train loss: 6.674052e-01
# train#680, train loss: 7.384512e-01
# train#690, train loss: 1.072374e+00
# train#700, train loss: 8.365133e-01
# train#710, train loss: 6.567606e-01
# train#720, train loss: 9.273041e-01
# train#730, train loss: 9.529827e-01
# train#740, train loss: 8.065412e-01
# train#750, train loss: 8.657173e-01
# train#760, train loss: 8.345085e-01
# train#770, train loss: 9.720276e-01
# train#780, train loss: 9.139366e-01
# train#790, train loss: 5.503603e-01
# train#800, train loss: 6.703406e-01
# ('initial:', array([-81., -81., -80., -78., -75., -73., -71., -70., -69., -67., -68.,
#        -69., -69., -69., -69., -70., -71., -70., -71., -72., -72., -72.,
#        -71., -71., -71., -70., -69., -69., -69., -69.]))
# prediction#1, output: -68.754234
# prediction#2, output: -68.550201
# prediction#3, output: -68.314499
# prediction#4, output: -68.104179
# prediction#5, output: -67.942390
# prediction#6, output: -67.794991
# prediction#7, output: -67.720703
# prediction#8, output: -67.646606
# prediction#9, output: -67.622131
# prediction#10, output: -67.588799
# prediction#11, output: -67.580803
# prediction#12, output: -67.562927
# prediction#13, output: -67.555557
# prediction#14, output: -67.538864
# prediction#15, output: -67.525215
# prediction#16, output: -67.503227
# prediction#17, output: -67.479492
# prediction#18, output: -67.446526
# prediction#19, output: -67.410614
# prediction#20, output: -67.369507
# prediction#21, output: -67.325676
# prediction#22, output: -67.280006
# prediction#23, output: -67.239632
# prediction#24, output: -67.198730
# prediction#25, output: -67.057808
# prediction#26, output: -67.125793
# prediction#27, output: -67.710190
# prediction#28, output: -67.972084
# prediction#29, output: -67.980911
# prediction#30, output: -67.958839
# prediction#31, output: -67.935196
# prediction#32, output: -67.924072
# prediction#33, output: -67.916634
# prediction#34, output: -67.913353
# prediction#35, output: -67.911102
# prediction#36, output: -67.910324
# prediction#37, output: -67.662292
# prediction#38, output: -67.721313
# prediction#39, output: -67.324402
# prediction#40, output: -66.754883
# prediction#41, output: -66.374596
# prediction#42, output: -65.932953
# prediction#43, output: -65.703781
# prediction#44, output: -65.579842
# prediction#45, output: -65.530945
# prediction#46, output: -65.525528
# prediction#47, output: -65.542130
# prediction#48, output: -65.566811
# prediction#49, output: -65.592003
# prediction#50, output: -65.612747
# prediction#51, output: -65.627449
# prediction#52, output: -65.635323
# prediction#53, output: -65.638222
# prediction#54, output: -65.636696
# prediction#55, output: -65.632782
# prediction#56, output: -65.633507
# prediction#57, output: -66.197868
# prediction#58, output: -67.044983
# prediction#59, output: -67.539505
# prediction#60, output: -67.742889
# prediction#61, output: -67.820694
# prediction#62, output: -67.696785
# prediction#63, output: -67.770760
# prediction#64, output: -67.421021
# prediction#65, output: -67.551239
# prediction#66, output: -67.185760
# prediction#67, output: -67.243042
# prediction#68, output: -67.785172
# prediction#69, output: -67.223549
# prediction#70, output: -66.462410
# prediction#71, output: -65.963058
# prediction#72, output: -65.675125
# prediction#73, output: -65.541672
# prediction#74, output: -65.499809
# prediction#75, output: -65.506042
# prediction#76, output: -65.533295
# prediction#77, output: -65.566414
# prediction#78, output: -65.596748
# prediction#79, output: -65.620125
# prediction#80, output: -65.634811
# prediction#81, output: -65.641426
# prediction#82, output: -65.641624
# prediction#83, output: -65.637856
# prediction#84, output: -65.632294
# prediction#85, output: -65.626785
# prediction#86, output: -65.622345
# prediction#87, output: -65.619484
# prediction#88, output: -66.178009
# prediction#89, output: -66.367172
# prediction#90, output: -66.779449
# prediction#91, output: -66.823509
# prediction#92, output: -66.957771
# prediction#93, output: -66.955025
# prediction#94, output: -66.219490
# prediction#95, output: -66.784142
# prediction#96, output: -66.617195
# prediction#97, output: -66.987129
# prediction#98, output: -66.904808
# prediction#99, output: -66.154877
# prediction#100, output: -65.903053
# ('outputs:', array([-68.75423431, -68.55020142, -68.3144989 , -68.10417938,
#        -67.94239044, -67.79499054, -67.72070312, -67.64660645,
#        -67.62213135, -67.58879852, -67.58080292, -67.56292725,
#        -67.55555725, -67.53886414, -67.52521515, -67.50322723,
#        -67.47949219, -67.44652557, -67.41061401, -67.36950684,
#        -67.32567596, -67.28000641, -67.23963165, -67.19873047,
#        -67.05780792, -67.12579346, -67.71018982, -67.97208405,
#        -67.98091125, -67.95883942, -67.93519592, -67.92407227,
#        -67.91663361, -67.91335297, -67.91110229, -67.9103241 ,
#        -67.66229248, -67.72131348, -67.32440186, -66.75488281,
#        -66.37459564, -65.93295288, -65.70378113, -65.57984161,
#        -65.53094482, -65.52552795, -65.54212952, -65.56681061,
#        -65.59200287, -65.61274719, -65.62744904, -65.63532257,
#        -65.63822174, -65.63669586, -65.63278198, -65.63350677,
#        -66.19786835, -67.04498291, -67.539505  , -67.7428894 ,
#        -67.82069397, -67.69678497, -67.77075958, -67.42102051,
#        -67.55123901, -67.1857605 , -67.24304199, -67.78517151,
#        -67.22354889, -66.46240997, -65.96305847, -65.67512512,
#        -65.54167175, -65.49980927, -65.50604248, -65.53329468,
#        -65.56641388, -65.59674835, -65.62012482, -65.6348114 ,
#        -65.64142609, -65.64162445, -65.63785553, -65.6322937 ,
#        -65.62678528, -65.62234497, -65.61948395, -66.17800903,
#        -66.36717224, -66.77944946, -66.82350922, -66.9577713 ,
#        -66.95502472, -66.21949005, -66.78414154, -66.61719513,
#        -66.98712921, -66.90480804, -66.15487671, -65.90305328]))

# %%
output = np.load('output.npy')
df = pd.DataFrame({'supervisor': train_data[length_of_initial_sequences:length_of_initial_sequences+num_of_prediction_epochs,1], 'prediction': output})
df.plot()
