# %%
import tensorflow as tf
import numpy as np
import random

# %%
def make_mini_batch(train_data, size_of_mini_batch, length_of_sequences):
    inputs  = np.empty(0)
    outputs = np.empty(0)
    for _ in range(size_of_mini_batch):
        index   = random.randint(0, len(train_data) - length_of_sequences)
        part    = train_data[index:index + length_of_sequences]
        inputs  = np.append(inputs, part[:, 0])
        outputs = np.append(outputs, part[-1, 1])
    inputs  = inputs.reshape(-1, length_of_sequences, 1)
    outputs = outputs.reshape(-1, 1)
    return (inputs, outputs)

# %%
def make_prediction_initial(train_data, index, length_of_sequences):
    return train_data[index:index + length_of_sequences, 0]

# %%
train_data_path             = "./rssi_next.npy"
num_of_input_nodes          = 1
num_of_hidden_nodes         = 2
num_of_output_nodes         = 1
length_of_sequences         = 30
num_of_training_epochs      = 800
length_of_initial_sequences = 30
num_of_prediction_epochs    = 100
size_of_mini_batch          = 1
learning_rate               = 0.5
forget_bias                 = 1.0

# %%
train_data = np.load(train_data_path)

# %%
# random seed fix
random.seed(0)
np.random.seed(0)
tf.set_random_seed(0)

# %%
#optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
#optimizer = tf.train.AdagradOptimizer(learning_rate=learning_rate)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

# %%
with tf.Graph().as_default():
    input_ph      = tf.placeholder(tf.float32, [None, length_of_sequences, num_of_input_nodes], name="input")
    supervisor_ph = tf.placeholder(tf.float32, [None, num_of_output_nodes], name="supervisor")
    istate_ph     = tf.placeholder(tf.float32, [None, num_of_hidden_nodes * 2], name="istate")

    with tf.name_scope("inference") as scope:
        weight1_var = tf.Variable(tf.truncated_normal([num_of_input_nodes, num_of_hidden_nodes], stddev=0.1), name="weight1")
        weight2_var = tf.Variable(tf.truncated_normal([num_of_hidden_nodes, num_of_output_nodes], stddev=0.1), name="weight2")
        bias1_var   = tf.Variable(tf.truncated_normal([num_of_hidden_nodes], stddev=0.1), name="bias1")
        bias2_var   = tf.Variable(tf.truncated_normal([num_of_output_nodes], stddev=0.1), name="bias2")

        in1 = tf.transpose(input_ph, [1, 0, 2])         # (batch, sequence, data) -> (sequence, batch, data)
        in2 = tf.reshape(in1, [-1, num_of_input_nodes]) # (sequence, batch, data) -> (sequence * batch, data)
        in3 = tf.matmul(in2, weight1_var) + bias1_var
        in4 = tf.split(0, length_of_sequences, in3)     # sequence * (batch, data)

        cell = tf.nn.rnn_cell.BasicLSTMCell(num_of_hidden_nodes, forget_bias=forget_bias)
        rnn_output, states_op = tf.nn.rnn(cell, in4, initial_state=istate_ph)
        output_op = tf.matmul(rnn_output[-1], weight2_var) + bias2_var

    with tf.name_scope("loss") as scope:
        square_error = tf.reduce_mean(tf.square(output_op - supervisor_ph))
        loss_op      = square_error
        tf.scalar_summary("loss", loss_op)

    with tf.name_scope("training") as scope:
        training_op = optimizer.minimize(loss_op)

    summary_op = tf.merge_all_summaries()
    init = tf.initialize_all_variables()

    with tf.Session() as sess:
        saver = tf.train.Saver()
        summary_writer = tf.train.SummaryWriter("data", graph=sess.graph)
        sess.run(init)

        for epoch in range(num_of_training_epochs):
            inputs, supervisors = make_mini_batch(train_data, size_of_mini_batch, length_of_sequences)

            train_dict = {
                input_ph:      inputs,
                supervisor_ph: supervisors,
                istate_ph:     np.zeros((size_of_mini_batch, num_of_hidden_nodes * 2)),
            }
            sess.run(training_op, feed_dict=train_dict)

            if (epoch + 1) % 10 == 0:
                summary_str, train_loss = sess.run([summary_op, loss_op], feed_dict=train_dict)
                summary_writer.add_summary(summary_str, epoch)
                print("train#%d, train loss: %e" % (epoch + 1, train_loss))

        inputs  = make_prediction_initial(train_data, 0, length_of_initial_sequences)
        outputs = np.empty(0)
# train#790, train loss: 4.152229e+01
# train#800, train loss: 1.126035e+01
# ('initial:', array([-81., -81., -80., -78., -75., -73., -71., -70., -69., -67., -68.,
#        -69., -69., -69., -69., -70., -71., -70., -71., -72., -72., -72.,
#        -71., -71., -71., -70., -69., -69., -69., -69.]))
# prediction#1, output: -59.644356
# prediction#2, output: -59.644356
# prediction#3, output: -59.644356
# prediction#4, output: -59.644356
# prediction#5, output: -59.644356
# prediction#6, output: -59.644356
# prediction#7, output: -59.644356
# prediction#8, output: -59.644356
# prediction#9, output: -59.644356
# prediction#10, output: -59.644356
# prediction#11, output: -59.644356
# prediction#12, output: -59.644356
# prediction#13, output: -59.644356
# prediction#14, output: -59.644356
# prediction#15, output: -59.644356
# prediction#16, output: -59.644356
# prediction#17, output: -59.644356
# prediction#18, output: -59.644356
# prediction#19, output: -59.644356
# prediction#20, output: -59.644356
# prediction#21, output: -59.644356
# prediction#22, output: -59.644356
# prediction#23, output: -59.644356
# prediction#24, output: -59.644356
# prediction#25, output: -59.644356
# prediction#26, output: -59.644356
# prediction#27, output: -59.644356
# prediction#28, output: -59.644356
# prediction#29, output: -59.644356
# prediction#30, output: -59.644356
# prediction#31, output: -59.644356
# prediction#32, output: -59.644356
# prediction#33, output: -59.644356
# prediction#34, output: -59.644356
# prediction#35, output: -59.644356
# prediction#36, output: -59.644356
# prediction#37, output: -59.644356
# prediction#38, output: -59.644356
# prediction#39, output: -59.644356
# prediction#40, output: -59.644356
# prediction#41, output: -59.644356
# prediction#42, output: -59.644356
# prediction#43, output: -59.644356
# prediction#44, output: -59.644356
# prediction#45, output: -59.644356
# prediction#46, output: -59.644356
# prediction#47, output: -59.644356
# prediction#48, output: -59.644356
# prediction#49, output: -59.644356
# prediction#50, output: -59.644356
# prediction#51, output: -59.644356
# prediction#52, output: -59.644356
# prediction#53, output: -59.644356
# prediction#54, output: -59.644356
# prediction#55, output: -59.644356
# prediction#56, output: -59.644356
# prediction#57, output: -59.644356
# prediction#58, output: -59.644356
# prediction#59, output: -59.644356
# prediction#60, output: -59.644356
# prediction#61, output: -59.644356
# prediction#62, output: -59.644356
# prediction#63, output: -59.644356
# prediction#64, output: -59.644356
# prediction#65, output: -59.644356
# prediction#66, output: -59.644356
# prediction#67, output: -59.644356
# prediction#68, output: -59.644356
# prediction#69, output: -59.644356
# prediction#70, output: -59.644356
# prediction#71, output: -59.644356
# prediction#72, output: -59.644356
# prediction#73, output: -59.644356
# prediction#74, output: -59.644356
# prediction#75, output: -59.644356
# prediction#76, output: -59.644356
# prediction#77, output: -59.644356
# prediction#78, output: -59.644356
# prediction#79, output: -59.644356
# prediction#80, output: -59.644356
# prediction#81, output: -59.644356
# prediction#82, output: -59.644356
# prediction#83, output: -59.644356
# prediction#84, output: -59.644356
# prediction#85, output: -59.644356
# prediction#86, output: -59.644356
# prediction#87, output: -59.644356
# prediction#88, output: -59.644356
# prediction#89, output: -59.644356
# prediction#90, output: -59.644356
# prediction#91, output: -59.644356
# prediction#92, output: -59.644356
# prediction#93, output: -59.644356
# prediction#94, output: -59.644356
# prediction#95, output: -59.644356
# prediction#96, output: -59.644356
# prediction#97, output: -59.644356
# prediction#98, output: -59.644356
# prediction#99, output: -59.644356
# prediction#100, output: -59.644356
# ('outputs:', array([-59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577,
#        -59.64435577, -59.64435577, -59.64435577, -59.64435577]))
